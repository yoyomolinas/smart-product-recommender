# %%
import pandas as pd
from tqdm import tqdm
from PIL import Image
import numpy as np
from tensorflow import keras
import utils
import api

# %%
featex = api.API()
# Out:
# Loading feature extractor module..
# Loading data
#   0%|          | 53/99986 [00:00<03:11, 522.39it/s]
# Loading features
# 100%|██████████| 99986/99986 [03:10<00:00, 524.54it/s]

# %%
img = Image.open(featex.df.iloc[110]['local_path'])

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x1254 at 0x7F7D306EBE50>

# %%
img = utils.preprocess(img, size = (256, 256))
img = np.array(img)

# %%
featex._get_closest_neighbors(img)
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# 110         110           110             110
# 234         234           234             234
# 474         474           474             474
# 2             2             2               2
# 505         505           505             505
# 952         952           952             952
# 102         102           102             102
# 139         139           139             139
# 637         637           637             637
# 289         289           289             289
# 701         701           701             701
# 49           49            49              49
# 771         771           771             771
# 850         850           850             850
# 386         386           386             386
# 176         176           176             176
#
#                                        productcategory  \
# 110             [" Markalar","Limon","Giyim","Gömlek"]
# 234           [" Markalar","İpekyol","Giyim","Gömlek"]
# 474  [" Markalar","Altinyildiz Classic","Giyim","Gö...
# 2               [" Markalar","Limon","Giyim","Gömlek"]
# 505          [" Markalar","Bvlgari","Parfüm","Parfüm"]
# 952      [" Markalar","The North Face","Giyim","Mont"]
# 102    [" Markalar","U.S. Polo Assn.","Giyim","Kazak"]
# 139    [" Markalar","U.S. Polo Assn.","Giyim","Kazak"]
# 637             [" Markalar","Network","Giyim","Mont"]
# 289  [" Markalar","House Of Camellia","Giyim","Ceket"]
# 701         [" Markalar","Dockers","Giyim","Pantolon"]
# 49          [" Markalar","Fabrika","Giyim","Pantolon"]
# 771  [" Markalar","Estee Lauder","Cilt / Vücut Bakı...
# 850            [" Markalar","Network","Giyim","Kaban"]
# 386            [" Markalar","Network","Giyim","Kaban"]
# 176  [" Markalar","Yves Saint Laurent","Makyaj","Ma...
#
#                                            productname  \
# 110                            Limon Hakim Yaka Gömlek
# 234                                     İpekyol Gömlek
# 474                         Altinyildiz Classic Gömlek
# 2                                        Limon  Gömlek
# 505                                     Bvlgari Parfüm
# 952                                The North Face Mont
# 102                             U.S. Polo Assn.  Kazak
# 139                             U.S. Polo Assn.  Kazak
# 637                                       Network Mont
# 289                        House Of Camellia Mor Ceket
# 701                                   Dockers Pantolon
# 49                Fabrika Dar Kesim Gabardin  Pantolon
# 771                         Estee Lauder  Nemlendirici
# 850                                      Network Kaban
# 386                                      Network Kaban
# 176  Yves Saint Laurent Touche Eclat Blur Primer Ba...
#
#                                        productimageurl  \
# 110  https://statics.boyner.com.tr/productimages/52...
# 234  https://statics.boyner.com.tr/productimages/52...
# 474  https://statics.boyner.com.tr/productimages/52...
# 2    https://statics.boyner.com.tr/productimages/51...
# 505  https://statics.boyner.com.tr/productimages/51...
# 952  https://statics.boyner.com.tr/productimages/52...
# 102  https://statics.boyner.com.tr/productimages/52...
# 139  https://statics.boyner.com.tr/productimages/52...
# 637  https://statics.boyner.com.tr/productimages/52...
# 289  https://statics.boyner.com.tr/productimages/52...
# 701  https://statics.boyner.com.tr/productimages/52...
# 49   https://statics.boyner.com.tr/productimages/52...
# 771  https://statics.boyner.com.tr/productimages/52...
# 850  https://statics.boyner.com.tr/productimages/52...
# 386  https://statics.boyner.com.tr/productimages/52...
# 176  https://statics.boyner.com.tr/productimages/51...
#
#                                             producturl  productprice language  \
# 110  https://www.boyner.com.tr/limon-gomlek-627199-...         29.99    tr_TR
# 234  https://www.boyner.com.tr/ipekyol-gomlek-62715...         91.00    tr_TR
# 474  https://www.boyner.com.tr/altinyildiz-classic-...         99.99    tr_TR
# 2    https://www.boyner.com.tr/limon-gomlek-659425-...         27.50    tr_TR
# 505  https://www.boyner.com.tr/bvlgari-parfum-46673...        363.00    tr_TR
# 952  https://www.boyner.com.tr/the-north-face-mont-...        839.00    tr_TR
# 102  https://www.boyner.com.tr/u.s.-polo-assn.-kaza...         59.95    tr_TR
# 139  https://www.boyner.com.tr/u.s.-polo-assn.-kaza...         59.95    tr_TR
# 637  https://www.boyner.com.tr/network-mont-645934-...        494.50    tr_TR
# 289  https://www.boyner.com.tr/house-of-camellia-ce...         89.99    tr_TR
# 701  https://www.boyner.com.tr/dockers-pantolon-621...        125.93    tr_TR
# 49   https://www.boyner.com.tr/fabrika-pantolon-666...        199.99    tr_TR
# 771  https://www.boyner.com.tr/estee-lauder-nemlend...        500.00    tr_TR
# 850  https://www.boyner.com.tr/network-kaban-640260...        749.50    tr_TR
# 386  https://www.boyner.com.tr/network-kaban-640260...        749.50    tr_TR
# 176  https://www.boyner.com.tr/yves-saint-laurent-m...        195.00    tr_TR
#
#                      local_path  category  \
# 110  data/boyner_images/110.jpg         2
# 234  data/boyner_images/234.jpg         2
# 474  data/boyner_images/474.jpg         2
# 2      data/boyner_images/2.jpg         2
# 505  data/boyner_images/505.jpg         2
# 952  data/boyner_images/952.jpg         2
# 102  data/boyner_images/102.jpg         2
# 139  data/boyner_images/139.jpg         2
# 637  data/boyner_images/637.jpg         2
# 289  data/boyner_images/289.jpg         2
# 701  data/boyner_images/701.jpg         2
# 49    data/boyner_images/49.jpg         2
# 771  data/boyner_images/771.jpg         2
# 850  data/boyner_images/850.jpg         2
# 386  data/boyner_images/386.jpg         2
# 176  data/boyner_images/176.jpg         2
#
#                                                feature
# 110  [1.1839531907753553e-05, 0.005334122106432915,...
# 234  [5.8686864576884545e-06, 0.0059317778795957565...
# 474  [1.7530439890833804e-06, 0.006963924504816532,...
# 2    [0.00043584671220742166, 0.03651227056980133, ...
# 505  [3.491254392429255e-05, 0.11222820729017258, 0...
# 952  [0.0012000701390206814, 0.0233865138143301, 0....
# 102  [8.428244473179802e-05, 0.023535802960395813, ...
# 139  [8.428244473179802e-05, 0.023535802960395813, ...
# 637  [7.450793054886162e-05, 0.005311832297593355, ...
# 289  [3.0324233648570953e-06, 0.032304976135492325,...
# 701  [0.00016061143833212554, 0.010585404001176357,...
# 49   [6.078582373447716e-05, 0.04901920258998871, 0...
# 771  [7.647613529115915e-06, 0.0008868097211234272,...
# 850  [0.0004253972147125751, 0.013648761436343193, ...
# 386  [0.0004253972147125751, 0.013648761436343193, ...
# 176  [0.00011992426152573898, 0.02342332899570465, ...

# %%
featex.encode_base_64(img)
# Out:
# b'...'

# %%
import random
import numpy as np
from itertools import permutations
from tensorflow import keras
import time
from PIL import Image
import cv2
import utils
from tqdm import tqdm
from os.path import join
import pickle
import time
import multiprocessing
from imgaug import augmenters as iaa

# %%
# load data
dt = utils.DirectoryTree("data/Category and Attribute Prediction Benchmark/")
with open(join(dt.Anno.path, 'meta.pickle'), 'rb' ) as f:
    data = pickle.load(f)

# %%
class BatchGenerator(keras.utils.Sequence):
    """
    This batch generator generates batches of augmented images, labels, and attributes.
    """
    def __init__(self,
                image_paths,
                bboxes,
                categories,
                attributes,
                eval_status,
                num_categories = 50,
                num_attributes = 10000,
                batch_size = 64,
                shuffle = True, 
                image_size = (128, 128),
                jitter = False,
                crop = False,
                mode = 'train'):
        """
        :param image_size: image_size in (width, height) format
        """
        assert mode in ['test', 'train', 'val']
        assert image_size[0] == image_size[1], \
            "Expected square image size please correct image_size argument accordingly"
        self.mode = mode
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.image_size = image_size
        self.eval_status = np.array(eval_status)
        self.index = np.arange(0, len(image_paths))[self.eval_status == self.mode]
        np.random.seed(1)
        np.random.shuffle(self.index)
        self.image_paths = image_paths
        self.bboxes = bboxes
        self.categories = categories
        self.attributes = attributes
        self.num_categories = num_categories
        self.num_attributes = num_attributes
        self.aug_pipe = self.get_aug_pipeline(p = 0.5)  
        self.jitter = jitter
        self.crop = crop
        
        
    def __len__(self):
        """
        :return :Number of batches in this generator
        """
        return int(len(self.index) / self.batch_size)

    def on_epoch_end(self):
        """
        Function called in the end of every epoch.
        """
        if self.shuffle:
            np.random.shuffle(self.index)

    def __get_bounds__(self, idx):
        """
        Retrieve bounds for specified index
        :param idx: index 
        :return left bound, right bound:
        """
        #Define bounds of the image range in current batch
        l_bound = idx*self.batch_size #left bound
        r_bound = (idx+1)*self.batch_size #right bound

        if r_bound > len(self.image_paths):
            r_bound = len(self.image_paths)
            # Keep batch size stable when length of images is not a multiple of batch size.
            l_bound = r_bound - self.batch_size
        return l_bound, r_bound

    def preprocess(self, image, bbox, size):
        """
        :param image: PIL image
        :param bbox: bounding box in (x1, y1, x2, y2) format
        :return image: numpy array
        """
        temp_image = image
        if self.crop:
            temp_image = temp_image.crop(bbox)
        temp_image = utils.resampling_with_original_ratio(temp_image, self.image_size)
        temp_image = np.array(temp_image)
        if self.jitter:
            temp_image = self.aug_pipe.augment_image(temp_image)
        return temp_image

    def get_aug_pipeline(self, p = 0.2):
        # Helper Lambda

        sometimes = lambda aug: iaa.Sometimes(p, aug)

        aug_pipe = iaa.Sequential(
            [
                iaa.SomeOf(
                    (1, 2),
                    [
                        # sometimes(iaa.Fliplr(1.)),  # horizontally flip 50% of all images
                        sometimes(iaa.Crop(percent=(0, 0.15))),  # crop images by 0-10% of their height/width
                        sometimes(iaa.Affine(translate_percent={"x": (-0.15, 0.15), "y": (-0.15, 0.15)}))
                    ],
                    random_order=True
                ),
                iaa.OneOf(
                    [
                        sometimes(iaa.Multiply((0.5, 0.5), per_channel=0.5)),
                        iaa.GaussianBlur((0, 3.0)),  # blur images with a sigma between 0 and 3.0
                        iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.04 * 255), per_channel=0.5),
                        
                    ]
                )
            ],
            random_order=True
        )

        return aug_pipe  

    def __getitem__(self, i):
        """
        Abstract function from Sequence class - called every iteration in model.fit_generator function.
        :param i: batch id
        :return X, [Y_map, Y_cat, Y_attr]
        """
        X, Y_cat, Y_attr = [], [], []
        l_bound, r_bound = self.__get_bounds__(i)
        for j in range(l_bound, r_bound):
            idx = self.index[j]
            img = Image.open(self.image_paths[idx])
            bbox = (self.bboxes[idx][0], self.bboxes[idx][2], self.bboxes[idx][1], self.bboxes[idx][3]) # (x1, y1, x2, y2)
            img_arr = self.preprocess(img, bbox, size= self.image_size)
            cat_vec = np.zeros(self.num_categories)
            cat_vec[self.categories[idx]] = 1
            attr_vec = self.attributes[idx]
            X.append(img_arr)
            Y_cat.append(cat_vec)
            Y_attr.append(attr_vec)
        X = np.array(X)
        Y_out = [np.array(Y_cat), np.array(Y_attr)]
        return X, Y_out

# %%
args_dict = dict(
    image_paths = list(map(lambda path: join(dt.Img.path, path), data['img_names'])), 
    bboxes = data['bbox_coords'],
    categories=data['cat_labels'],
    attributes=data['attr_labels'],
    eval_status=data['eval_status'],
    batch_size=64,
    image_size=(256, 256),
    shuffle = True,
    jitter = True,
    crop = True,
    mode = 'test'
)

gen = BatchGenerator(**args_dict)

# %%
def f(idx, queue, args_dict):
    gen = BatchGenerator(**args_dict)
    i = 0
    for _ in range(10000):
        tic = time.time()
        res = gen.__getitem__(i)
        toc = time.time()
        i += 1
        queue.put(res)
        
out_queue = multiprocessing.Queue()
processes = [multiprocessing.Process(target = f, args = (i, out_queue, args_dict, )) for i in range(4)]

# %%
[p.start() for p in processes]
for i in tqdm(range(40000)):
    res = out_queue.get()
# Out:
#   0%|          | 0/40000 [00:00<?, ?it/s]
#
#   0%|          | 1/40000 [00:00<4:35:11,  2.42it/s]
#
#   0%|          | 4/40000 [00:00<3:22:01,  3.30it/s]
#
#   0%|          | 5/40000 [00:00<2:58:31,  3.73it/s]
#
#   0%|          | 6/40000 [00:00<2:25:07,  4.59it/s]
#
#   0%|          | 9/40000 [00:01<2:09:18,  5.15it/s]
#
#   0%|          | 11/40000 [00:01<1:41:11,  6.59it/s]
#
#   0%|          | 13/40000 [00:01<1:43:42,  6.43it/s]
#
#   0%|          | 16/40000 [00:01<1:26:19,  7.72it/s]
#
#   0%|          | 18/40000 [00:02<1:28:01,  7.57it/s]
#
#   0%|          | 20/40000 [00:02<1:15:50,  8.79it/s]
#
#   0%|          | 22/40000 [00:02<1:19:38,  8.37it/s]
#
#   0%|          | 24/40000 [00:02<1:09:23,  9.60it/s]
#
#   0%|          | 26/40000 [00:02<1:16:31,  8.71it/s]
#
#   0%|          | 28/40000 [00:03<1:09:42,  9.56it/s]
#
#   0%|          | 30/40000 [00:03<1:16:11,  8.74it/s]
#
#   0%|          | 32/40000 [00:03<1:07:47,  9.83it/s]
#
#   0%|          | 34/40000 [00:03<1:17:55,  8.55it/s]
#
#   0%|          | 36/40000 [00:04<1:06:30, 10.01it/s]
#
#   0%|          | 38/40000 [00:04<1:19:06,  8.42it/s]
#
#   0%|          | 40/40000 [00:04<1:05:45, 10.13it/s]
#
#   0%|          | 42/40000 [00:04<1:18:15,  8.51it/s]
#
#   0%|          | 44/40000 [00:04<1:06:41,  9.99it/s]
#
#   0%|          | 46/40000 [00:05<1:16:38,  8.69it/s]
#
#   0%|          | 48/40000 [00:05<1:05:11, 10.21it/s]
#
#   0%|          | 50/40000 [00:05<1:18:56,  8.44it/s]
#
#   0%|          | 52/40000 [00:05<1:13:40,  9.04it/s]  File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 633, in augment_images
#     hooks=hooks
# Process Process-44:
# Process Process-47:
# Process Process-45:
# Process Process-46:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-39-29a8348a8b4c>", line 6, in f
#     res = gen.__getitem__(i)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-ba9a603e1d04>", line 129, in __getitem__
#     img_arr = self.preprocess(img, bbox, size= self.image_size)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-39-29a8348a8b4c>", line 6, in f
#     res = gen.__getitem__(i)
#   File "<ipython-input-6-ba9a603e1d04>", line 84, in preprocess
#     temp_image = self.aug_pipe.augment_image(temp_image)
#   File "<ipython-input-6-ba9a603e1d04>", line 129, in __getitem__
#     img_arr = self.preprocess(img, bbox, size= self.image_size)
#   File "<ipython-input-39-29a8348a8b4c>", line 6, in f
#     res = gen.__getitem__(i)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 571, in augment_image
#     return self.augment_images([image], hooks=hooks)[0]
#   File "<ipython-input-39-29a8348a8b4c>", line 6, in f
#     res = gen.__getitem__(i)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 695, in augment_images
#     hooks=hooks
#   File "<ipython-input-6-ba9a603e1d04>", line 84, in preprocess
#     temp_image = self.aug_pipe.augment_image(temp_image)
#   File "<ipython-input-6-ba9a603e1d04>", line 129, in __getitem__
#     img_arr = self.preprocess(img, bbox, size= self.image_size)
#   File "<ipython-input-6-ba9a603e1d04>", line 129, in __getitem__
#     img_arr = self.preprocess(img, bbox, size= self.image_size)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 571, in augment_image
#     return self.augment_images([image], hooks=hooks)[0]
#   File "<ipython-input-6-ba9a603e1d04>", line 84, in preprocess
#     temp_image = self.aug_pipe.augment_image(temp_image)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2961, in _augment_images
#     images, random_state, parents, hooks, "augment_images")
#   File "<ipython-input-6-ba9a603e1d04>", line 84, in preprocess
#     temp_image = self.aug_pipe.augment_image(temp_image)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 571, in augment_image
#     return self.augment_images([image], hooks=hooks)[0]
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 695, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2995, in _augment_augmentables
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 571, in augment_image
#     return self.augment_images([image], hooks=hooks)[0]
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2961, in _augment_images
#     images, random_state, parents, hooks, "augment_images")
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 633, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 695, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2995, in _augment_augmentables
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 695, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 3278, in _augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 633, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2961, in _augment_images
#     images, random_state, parents, hooks, "augment_images")
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2995, in _augment_augmentables
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/arithmetic.py", line 1266, in _augment_images
#     values = self.value.draw_samples(sample_shape, random_state=rs)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 3278, in _augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2961, in _augment_images
#     images, random_state, parents, hooks, "augment_images")
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/parameters.py", line 351, in draw_samples
#     random_state)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 633, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/parameters.py", line 954, in _draw_samples
#     loc = self.loc.draw_sample(random_state=random_state)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2995, in _augment_augmentables
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 3571, in _augment_images
#     parents, hooks, _augfunc)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 633, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/parameters.py", line 324, in draw_sample
#     return self.draw_samples(1, random_state=random_state)[0]
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 3645, in _augment_augmentables
#     augmentables_this_list, parents + [self], hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/parameters.py", line 352, in draw_samples
#     random_state.advance_()
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 3262, in _augment_images
#     random_state)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 3568, in _augfunc
#     return augs_.augment_images(augmentables_, parents_, hooks_)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/random.py", line 361, in advance_
#     advance_generator_(self.generator)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 633, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 633, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 3222, in _get_augmenter_active
#     nn = self._get_n(nb_rows, random_state)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 3278, in _augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/random.py", line 1341, in advance_generator_
#     _advance_generator_np117_(generator)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2961, in _augment_images
#     images, random_state, parents, hooks, "augment_images")
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 633, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/random.py", line 1345, in _advance_generator_np117_
#     _reset_generator_cache_np117_(generator)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/arithmetic.py", line 1266, in _augment_images
#     values = self.value.draw_samples(sample_shape, random_state=rs)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/random.py", line 1101, in _reset_generator_cache_np117_
#     state = _get_generator_state_np117(generator)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/parameters.py", line 351, in draw_samples
#     random_state)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/random.py", line 1226, in _get_generator_state_np117
#     return generator.bit_generator.state
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 3210, in _get_n
#     return self.n.draw_samples((nb_images,), random_state=random_state)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/parameters.py", line 349, in draw_samples
#     samples = self._draw_samples(
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 2995, in _augment_augmentables
#     hooks=hooks
# KeyboardInterrupt
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/parameters.py", line 961, in _draw_samples
#     loc, scale, size=size
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/meta.py", line 633, in augment_images
#     hooks=hooks
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/random.py", line 584, in normal
#     return self.generator.normal(loc=loc, scale=scale, size=size)
# KeyboardInterrupt
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/size.py", line 1146, in _augment_images
#     samples.pad_cval, self.keep_size)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/augmenters/size.py", line 77, in _crop_and_pad_arr
#     mode=pad_mode, cval=pad_cval)
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/imgaug/imgaug.py", line 1776, in pad
#     return np.copy(arr)
#   File "<__array_function__ internals>", line 6, in copy
#   File "/home/yoelmolinas/.conda/envs/cpu/lib/python3.7/site-packages/numpy/lib/function_base.py", line 790, in copy
#     return array(a, order=order, copy=True)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-952686589be2> in <module>
#       1 [p.start() for p in processes]
#       2 for i in tqdm(range(40000)):
# ----> 3     res = out_queue.get()
#
# ~/.conda/envs/cpu/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#      92         if block and timeout is None:
#      93             with self._rlock:
# ---> 94                 res = self._recv_bytes()
#      95             self._sem.release()
#      96         else:
#
# ~/.conda/envs/cpu/lib/python3.7/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# ~/.conda/envs/cpu/lib/python3.7/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# ~/.conda/envs/cpu/lib/python3.7/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

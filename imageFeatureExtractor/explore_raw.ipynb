# %%
import pandas as pd

# %%
df = pd.read_csv("data/meta/lcwaikiki100k.csv")

# %%
df
# Out:
#                                       productname  \
# 0          Polo Yaka Kısa Kollu Pike Basic Tişört
# 1                  Kısa Kollu V Yaka Basic Tişört
# 2                   879 Regular Fit Jean Pantolon
# 3                      Standart Kalıp Deniz Şortu
# 4                Polo Yaka Kısa Kollu Pike Tişört
# ...                                           ...
# 99995             Çiçek İşlemeli Tül Abiye Elbise
# 99996                    Çift Kişilik Pike Takımı
# 99997  Kız Çocuk Yazı Baskılı Pamuklu Spor Tişört
# 99998                           Pamuklu Düz Atlet
# 99999           Kız Bebek Yazı Baskılı Sweatshirt
#
#                              productcategory  \
# 0                         ["Erkek","Tişört"]
# 1                         ["Erkek","Tişört"]
# 2                           ["Erkek","Jean"]
# 3                           ["Erkek","Mayo"]
# 4                         ["Erkek","Tişört"]
# ...                                      ...
# ...
